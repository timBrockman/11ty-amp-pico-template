# %% [markdown]
# <a href="https://colab.research.google.com/github/timBrockman/11ty-amp-pico-template/blob/master/Chapter_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url="https://data.cdc.gov/api/views/jiwm-ppbh/rows.csv?accessType=DOWNLOAD"
heart_df = pd.read_csv(url, index_col=0)

# %%
heart_df.head()
# Out:
#      LocationAbbr    LocationDesc GeographicLevel DataSource  \
# Year
# 2019           AK  Aleutians East          County       NVSS
# 2019           AK  Aleutians West          County       NVSS
# 2019           AK       Anchorage          County       NVSS
# 2019           AK          Bethel          County       NVSS
# 2019           AK     Bristol Bay          County       NVSS
#
#                         Class                    Topic  Data_Value  \
# Year
# 2019  Cardiovascular Diseases  Heart Disease Mortality       182.4
# 2019  Cardiovascular Diseases  Heart Disease Mortality       172.6
# 2019  Cardiovascular Diseases  Heart Disease Mortality       255.6
# 2019  Cardiovascular Diseases  Heart Disease Mortality       343.4
# 2019  Cardiovascular Diseases  Heart Disease Mortality         NaN
#
#              Data_Value_Unit  \
# Year
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# ...

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59094 entries, 2019 to 2019
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LocationAbbr                59094 non-null  object
#  1   LocationDesc                59094 non-null  object
#  2   GeographicLevel             59094 non-null  object
#  3   DataSource                  59094 non-null  object
#  4   Class                       59094 non-null  object
#  5   Topic                       59094 non-null  object
#  6   Data_Value                  33087 non-null  float64
#  7   Data_Value_Unit             59094 non-null  object
#  8   Data_Value_Type             59094 non-null  object
#  9   Data_Value_Footnote_Symbol  26007 non-null  object
#  10  Data_Value_Footnote         26007 non-null  object
#  11  StratificationCategory1     59094 non-null  object
#  12  Stratification1             59094 non-null  object
# ...

# %%
#heart_df = pd.read_csv('/content/drive/MyDrive/Heart_Disease_Mortality_Data_Among_US_Adults__35___by_State_Territory_and_County___2019-2021.csv', on_bad_lines='skip', engine="python")
heart_df.head()
# Out:
#      LocationAbbr    LocationDesc GeographicLevel DataSource  \
# Year
# 2019           AK  Aleutians East          County       NVSS
# 2019           AK  Aleutians West          County       NVSS
# 2019           AK       Anchorage          County       NVSS
# 2019           AK          Bethel          County       NVSS
# 2019           AK     Bristol Bay          County       NVSS
#
#                         Class                    Topic  Data_Value  \
# Year
# 2019  Cardiovascular Diseases  Heart Disease Mortality       182.4
# 2019  Cardiovascular Diseases  Heart Disease Mortality       172.6
# 2019  Cardiovascular Diseases  Heart Disease Mortality       255.6
# 2019  Cardiovascular Diseases  Heart Disease Mortality       343.4
# 2019  Cardiovascular Diseases  Heart Disease Mortality         NaN
#
#              Data_Value_Unit  \
# Year
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# ...

# %%
heart_df.isnull().sum()
# Out:
# LocationAbbr                      0
# LocationDesc                      0
# GeographicLevel                   0
# DataSource                        0
# Class                             0
# Topic                             0
# Data_Value                    26007
# Data_Value_Unit                   0
# Data_Value_Type                   0
# Data_Value_Footnote_Symbol    33087
# Data_Value_Footnote           33087
# StratificationCategory1           0
# Stratification1                   0
# StratificationCategory2           0
# Stratification2                   0
# TopicID                           0
# LocationID                        0
# Y_lat                            18
# X_lon                            18
# dtype: int64

# %%
heart_df.Stratification2.unique()
# Out:
# array(['Overall', 'White', 'Black', 'Hispanic',
#        'Asian and Pacific Islander', 'American Indian and Alaskan Native'],
#       dtype=object)

# %%
import seaborn as sns

# %%
sns.violinplot( x="Stratification2", y="Data_Value", data=heart_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-68243fe4eb3c> in <cell line: 1>()
# ----> 1 sns.violinplot( x="Stratification2", y="Data_Value", data=heart_df)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in violinplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, inner, split, width, dodge, gap, linewidth, linecolor, cut, gridsize, bw_method, bw_adjust, density_norm, common_norm, hue_norm, formatter, log_scale, native_scale, legend, scale, scale_hue, bw, inner_kws, ax, **kwargs)
#    1767     inner_kws = {} if inner_kws is None else inner_kws.copy()
#    1768
# -> 1769     p.plot_violins(
#    1770         width=width,
#    1771         dodge=dodge,
#
# ...

# %%
sns.distplot(heart_df['Data_Value'])
# Out:
# <ipython-input-20-d15275363afd>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(heart_df['Data_Value'])
# <Axes: xlabel='Data_Value', ylabel='Density'>
